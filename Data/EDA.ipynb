# %%
import numpy as np
import pandas as pd

df = pd.read_csv("vitalPeriodic.csv")
df.head(50)
# Out:
#     vitalperiodicid  patientunitstayid  observationoffset  temperature   sao2  \
# 0          47461452             142493                845          NaN    NaN
# 1          60289261             142493                130          NaN   99.0
# 2          60494832             142493                725          NaN   92.0
# 3          57835272             142493               1045          NaN   96.0
# 4          47737905             142493                855          NaN   95.0
# 5          57862241             142493               1095          NaN   91.0
# 6          60498737             142493                760          NaN   96.0
# 7          60297074             142493                180          NaN  100.0
# 8          47564327             142493                850          NaN   95.0
# 9          57848889             142493               1070          NaN   92.0
# 10         60496885             142493                740          NaN   93.0
# ...

# %%
df.shape
# Out:
# (1037527, 19)
